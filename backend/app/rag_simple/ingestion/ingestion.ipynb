# %%
import logging

from app.rag_simple.ingestion.chunk import split_documents
from app.rag_simple.ingestion.contextualize import add_context
from app.rag_simple.ingestion.load import load_documents
from app.rag_simple.ingestion.store import build_vectorstore

# %%
logging.basicConfig(level=logging.INFO)
documents = load_documents()
chunks = split_documents(documents)
# Out:
# INFO:app.rag_simple.ingestion.load:Loaded 1 documents from /home/alex/projects/RAG/calea_de_autovindecare/knowledge/ready_for_ingestion
# INFO:app.rag_simple.ingestion.chunk:Split into 96 chunks

# %%
# chunks = add_context(chunks, documents)
build_vectorstore(chunks)
len(chunks)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:app.rag_simple.ingestion.store:Vectorstore created with 96 chunks in Postgres table 'rag_simple_chunks'
# INFO:app.rag_simple.ingestion.store:Chunks saved to /home/alex/projects/RAG/full-stack-fastapi-template/backend/app/rag_simple/db/chunks.json (for BM25 index)
# 96

# %%
print(chunks[1])
# Out:
# page_content='Acest fragment face parte din secțiunea care descrie legătura emoțională și stările mentale asociate cu dezechilibrele organelor interne, oferind recomandări alimentare pentru restabilirea echilibrului inimii și intestinului subțire.
#
# ##### Inima și intestinul subțire
# Dacă inima și intestinul subțire sunt bolnave, vă excitați foarte ușor și râdeți prea mult fără motiv. Inima și intestinul subțire devin ușor de desumflat dacă luați prea multe fructe și sucuri de fructe.
# Pentru vindecarea condiției inimii și intestinului subțire, folosiți cereale care sunt prăjite, consumați ceai și diverse semințe, mici sâmburi rotunzi, diverse sortimente de fructe compacte. Legumele rădăcinoase sunt de asemenea recomandate. Dacă condiția acestor organe este bună, starea voastră de spirit devine opusă: foarte liniștită și calmă. Sunteți amabili.' metadata={'h4': 'Psihologia și Organele: Legătura Emoțională', 'h5': 'Inima și intestinul subțire', 'source': '05 seminar macrobiotica - Psihologia și Organele.md', 'original_text': '##### Inima și intestinul subțire\nDacă inima și intestinul subțire sunt bolnave, vă excitați foarte ușor și râdeți prea mult fără motiv. Inima și intestinul subțire devin ușor de desumflat dacă luați prea multe fructe și sucuri de fructe.\nPentru vindecarea condiției inimii și intestinului subțire, folosiți cereale care sunt prăjite, consumați ceai și diverse semințe, mici sâmburi rotunzi, diverse sortimente de fructe compacte. Legumele rădăcinoase sunt de asemenea recomandate. Dacă condiția acestor organe este bună, starea voastră de spirit devine opusă: foarte liniștită și calmă. Sunteți amabili.', 'context': 'Acest fragment face parte din secțiunea care descrie legătura emoțională și stările mentale asociate cu dezechilibrele organelor interne, oferind recomandări alimentare pentru restabilirea echilibrului inimii și intestinului subțire.'}
